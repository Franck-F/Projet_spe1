# %%
import pandas as pd
import numpy as np

# Chargement du fichier
# index_col=0 indique que la première colonne (les dates) sert d'index
df = pd.read_csv('data/raw/time_series_60min_singleindex.csv', 
                 index_col=0, 
                 parse_dates=True)

# Vérification rapide
print("Dimensions du DataFrame :", df.shape)
# Out:
# Dimensions du DataFrame : (50401, 299)

# %%
df.head()
# Out:
#                                  cet_cest_timestamp  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00  2015-01-01T00:00:00+0100
# 2015-01-01 00:00:00+00:00  2015-01-01T01:00:00+0100
# 2015-01-01 01:00:00+00:00  2015-01-01T02:00:00+0100
# 2015-01-01 02:00:00+00:00  2015-01-01T03:00:00+0100
# 2015-01-01 03:00:00+00:00  2015-01-01T04:00:00+0100
#
#                            AT_load_actual_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                 NaN
# 2015-01-01 00:00:00+00:00                              5946.0
# 2015-01-01 01:00:00+00:00                              5726.0
# 2015-01-01 02:00:00+00:00                              5347.0
# 2015-01-01 03:00:00+00:00                              5249.0
#
#                            AT_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                   NaN
# 2015-01-01 00:00:00+00:00                                6701.0
# ...

# %%
# Petit nettoyage immédiat : on supprime la colonne d'heure locale 
# (source d'erreurs avec le changement d'heure)
if 'cet_cest_timestamp' in df.columns:
    df = df.drop(columns=['cet_cest_timestamp'])

# %%
df.head()
# Out:
#                            AT_load_actual_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                 NaN
# 2015-01-01 00:00:00+00:00                              5946.0
# 2015-01-01 01:00:00+00:00                              5726.0
# 2015-01-01 02:00:00+00:00                              5347.0
# 2015-01-01 03:00:00+00:00                              5249.0
#
#                            AT_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                   NaN
# 2015-01-01 00:00:00+00:00                                6701.0
# 2015-01-01 01:00:00+00:00                                6593.0
# 2015-01-01 02:00:00+00:00                                6482.0
# 2015-01-01 03:00:00+00:00                                6454.0
#
#                            AT_price_day_ahead  AT_solar_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                 NaN                         NaN
# ...

# %%
df.describe()
# Out:
#        AT_load_actual_entsoe_transparency  \
# count                        50400.000000
# mean                          7070.148631
# std                           1400.263167
# min                            664.000000
# 25%                           5941.000000
# 50%                           7032.000000
# 75%                           8079.000000
# max                          10803.000000
#
#        AT_load_forecast_entsoe_transparency  AT_price_day_ahead  \
# count                          50400.000000        32845.000000
# mean                            7039.848552           33.934663
# std                             1355.382837           14.944863
# min                             3739.000000          -76.000000
# 25%                             5941.000000           25.000000
# 50%                             7018.000000           33.000000
# 75%                             7986.000000           42.000000
# max                            11608.000000          187.000000
#
# ...
